# %%
import sympy as sy
import numpy as np
from matplotlib import pyplot as plt

# %%
cons = np.sin(np.arange(50)) + np.sin(np.arange(50) / 5)*3 + np.random.rand(50)*2
prod = np.sin(np.arange(50))/1.2 + np.sin(np.arange(50) / 5)*2.5 + np.random.rand(50)
bat_max = 10
bat = 0
grid = 0

# %%
prod.sum(),cons.sum()
# Out:
# (70.5542590659521, 48.512408876921526)

# %%
plt.plot(prod -cons)
